# %% [markdown]
# <a href="https://colab.research.google.com/github/Kshitij879/PnemoniaDetection/blob/main/Copy_of_Pneumonia_Detection_model_VGG16_model(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h2> <b>What is Pneumonia?</b></h2>
#
# <p> <blockquote> Pneumonia is an inflammatory condition of the lung affecting primarily the small air sacs known as alveoli.Symptoms typically include some combination of productive or dry cough, chest pain, fever and difficulty breathing. The severity of the condition is variable. Pneumonia is usually caused by infection with viruses or bacteria and less commonly by other microorganisms, certain medications or conditions such as autoimmune diseases.Risk factors include cystic fibrosis, chronic obstructive pulmonary disease (COPD), asthma, diabetes, heart failure, a history of smoking, a poor ability to cough such as following a stroke and a weak immune system. Diagnosis is often based on symptoms and physical examination. Chest X-ray, blood tests, and culture of the sputum may help confirm the diagnosis.The disease may be classified by where it was acquired, such as community- or hospital-acquired or healthcare-associated pneumonia.</blockquote> </p>

# %% [markdown]
# ![pathogenesis-lower-respiratory-tract-infection-18.png](data:image/png;base64,...)

# %% [markdown]
# <h2> <b> Bacterial Pneumonia </b></h2>
#
# <p> Pneumonia caused by a bacterium is called bacterial pneumonia. There are many types of bacteria that may cause bacterial pneumonia, but the most common type Streptococcus pneumoniae.
#
# Common symptoms of bacterial pneumonia include:
#
# * Chest pain
# * Shortness of breath
# * Sputum that is yellow or green mucus while coughing
# * Chills
# * Fever
# * Fatigue
#
# Bacterial pneumonia requires antibiotics for treatment; ideally, the antibiotic will target the specific type of bacteria. Steroids may also be used to improve breathing.
#  </p>
# <h2> <b> Viral Pneumonia </b></h2>
# <p>Approximately 30% of pneumonia cases are viral. This type of pneumonia typically occurs as a secondary infection from other viruses such as influenza, coronavirus, parainfluenza, adenovirus, and respiratory syncytial virus (RSV).
#
# These types of viruses spread through air droplets. For example, a sneeze or a cough may cause sputum an air droplet to spread through the air, or the virus could land on a doorknob or a surface that is touched, then brought to the nose or mouth.
#
# Symptoms of viral pneumonia are similar, although there are differences:
#
# * A dry cough (note that there is rarely sputum produced with viral pneumonia)
# *Fever
# *Chills
# *Chest pain
# *Shortness of breath
#
# While bacterial pneumonia is treated with antibiotics, this treatment will not help bacterial pneumonia. Viruses are not receptive to antibiotics. Occasionally, antiviral medications may be prescribed.
# </p>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 

import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, AvgPool2D, MaxPool2D , Flatten , Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.callbacks import ReduceLROnPlateau
import cv2
import os

print(tf.__version__)
# Out:
# 2.3.0

# %% [markdown]
# # Load Data :

# %%
labels = ['PNEUMONIA', 'NORMAL']
img_size = 150
def get_input_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        diag= ""
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                # Reshaping images to preferred size
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) 
                if "bacteria" in img:
                    diag = [1,0,0] 
                elif "virus" in img:
                    diag = [0,1,0] 
                else:
                    diag = [0,0,1]              
                data.append([resized_arr, class_num, diag])
            except Exception as e:
                print(img, e)
    return np.array(data)

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train = get_input_data('/content/gdrive/My Drive/chest_xray/train')
test = get_input_data('/content/gdrive/My Drive/chest_xray/test')
val = get_input_data('/content/gdrive/My Drive/chest_xray/val')

# %% [markdown]
# # Data Visualization and processing

# %%
plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray', )
plt.title(label='Normal')

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(label='Bacterial Pneumonia')

plt.figure(figsize = (5,5))
plt.imshow(train[1][0], cmap='gray')
plt.title(label='Viral Pneumonia')
# Out:
# Text(0.5, 1.0, 'Viral Pneumonia')

# %% [markdown]
# <h2> Printing initial data :</h2>

# %%
def display_set(one_set, order = ["pneumonia bacteria", "pneumonia virus", "normal"]):
    l = []
    for i in one_set:
        if i[2] == [1,0,0]:
            diag = "pneumonia bacteria"
        elif i[2] == [0,1,0]:
            diag = "pneumonia virus"
        else:
            diag = "normal"
        l.append(diag)
    sns.set_style('darkgrid')
    sns.countplot(l, order = order)

# %%
display_set(train)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
display_set(val)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
display_set(test)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <h4> The training data seems unbalanced. The validation data has very less of viral pneumonia data.</h4>

# %% [markdown]
# <h3> Redistributing x-rays to create balanced train and validation dataset :</h3>

# %%
x_data = []
y_data = []

for feature, label, diag in train:
    x_data.append(feature)
    y_data.append(diag)

for feature, label, diag in test:
    x_data.append(feature)
    y_data.append(diag)
    
for feature, label, diag in val:
    x_data.append(feature)
    y_data.append(diag)

y_class_num = [np.where(np.asarray(r)==1)[0][0] for r in y_data]
sns.countplot(y_class_num).set_title('All data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'All data')

# %% [markdown]
# <h3> Resizing test dataset:

# %%
samples = pd.DataFrame(y_class_num, columns = ['class_num'])
samples['diag'] = y_data
samples['img'] = x_data

smallest_diag_count = samples['class_num'].value_counts().min()
print("number of sampels per category", smallest_diag_count)

class0 = samples[samples['class_num'] == 0].sample(smallest_diag_count)
class1 = samples[samples['class_num'] == 1].sample(smallest_diag_count)
class2 = samples[samples['class_num'] == 2].sample(smallest_diag_count)

samples_under = pd.concat([class0, class1, class2], axis=0)

x = samples_under['img'].tolist()
y = samples_under['diag'].tolist()
sns.countplot(samples_under['class_num']).set_title('Final data')
# Out:
# number of sampels per category 1498
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Final data')

# %% [markdown]
# Splitting data into 70% train, 15% validation and 15% test

# %%
# shuffling the samples to have matching ditributions regarding the differents sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True)
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_train]).set_title('Training data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Training data')

# %%
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, shuffle=False)
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_val]).set_title('Validation data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Validation data')

# %%
sns.countplot([np.where(np.asarray(r)==1)[0][0] for r in y_test]).set_title('Test data')
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Test data')

# %% [markdown]
# We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %% [markdown]
# DATA AUGMENTATION

# %%
# With data augmentation to prevent overfitting and handling the imbalance in dataset

train_datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range = 10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = False,  # randomly flip images
        vertical_flip=False)  # randomly flip images
train_datagen.fit(x_train)

valid_datagen = ImageDataGenerator()

test_datagen = ImageDataGenerator()


train_generator = train_datagen.flow(
    x_train,
    y_train,
    batch_size = 32)

validation_generator = valid_datagen.flow(
    x_val,
    y_val)

test_generator = test_datagen.flow(
    x_test,
    y_test)

# %% [markdown]
# TRAIN MODEL

# %%
model = Sequential()
model.add(Conv2D(input_shape=(150,150,1),filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))



model.add(Dense(units=3, activation="softmax"))
from keras.optimizers import Adam
opt = Adam(lr=0.0001)
model.compile(optimizer = opt , loss = 'categorical_crossentropy' , metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 75, 75, 128)       147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 37, 37, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 37, 37, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 37, 37, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 18, 18, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 18, 18, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 512)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 9, 9, 512)         2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              33558528
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 12291
# =================================================================
# Total params: 65,065,667
# Trainable params: 65,065,667
# Non-trainable params: 0
# _________________________________________________________________

# %%
class_weight = {0: 3, 1: 3, 2: 1}
loops = 100
history = []

for x in range(loops):
    history.append(model.fit(
            train_generator,
            steps_per_epoch=97,
            epochs=1,
            validation_data=test_generator,
            validation_steps=20,
            class_weight=class_weight))
# Out:
#  2/97 [..............................] - ETA: 10s - loss: 2.6048 - accuracy: 0.3594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0627s vs `on_train_batch_end` time: 0.1462s). Check your callbacks.
# 97/97 [==============================] - 22s 230ms/step - loss: 2.3739 - accuracy: 0.3307 - val_loss: 1.1318 - val_accuracy: 0.3281
#  2/97 [..............................] - ETA: 16s - loss: 2.4660 - accuracy: 0.3281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0663s vs `on_train_batch_end` time: 0.1401s). Check your callbacks.
# 97/97 [==============================] - 21s 221ms/step - loss: 2.3683 - accuracy: 0.3356 - val_loss: 1.2101 - val_accuracy: 0.3266
#  2/97 [..............................] - ETA: 17s - loss: 2.3624 - accuracy: 0.3125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0728s vs `on_train_batch_end` time: 0.1423s). Check your callbacks.
# 97/97 [==============================] - 22s 224ms/step - loss: 2.3477 - accuracy: 0.3343 - val_loss: 1.1988 - val_accuracy: 0.3266
#  2/97 [..............................] - ETA: 16s - loss: 2.3701 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0655s vs `on_train_batch_end` time: 0.1445s). Check your callbacks.
# 97/97 [==============================] - 22s 226ms/step - loss: 2.3278 - accuracy: 0.3288 - val_loss: 1.0983 - val_accuracy: 0.3281
#  2/97 [..............................] - ETA: 17s - loss: 2.3666 - accuracy: 0.2812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0685s vs `on_train_batch_end` time: 0.1472s). Check your callbacks.
# 97/97 [==============================] - 22s 231ms/step - loss: 2.1740 - accuracy: 0.4275 - val_loss: 0.7935 - val_accuracy: 0.6328
#  2/97 [..............................] - ETA: 17s - loss: 2.0492 - accuracy: 0.5938WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0697s vs `on_train_batch_end` time: 0.1504s). Check your callbacks.
# 97/97 [==============================] - 23s 234ms/step - loss: 1.8524 - accuracy: 0.6222 - val_loss: 0.6468 - val_accuracy: 0.7125
#  2/97 [..............................] - ETA: 17s - loss: 1.9700 - accuracy: 0.5156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0686s vs `on_train_batch_end` time: 0.1509s). Check your callbacks.
# 97/97 [==============================] - 23s 236ms/step - loss: 1.7168 - accuracy: 0.6589 - val_loss: 0.6210 - val_accuracy: 0.7188
#  2/97 [..............................] - ETA: 17s - loss: 1.6808 - accuracy: 0.7031WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0701s vs `on_train_batch_end` time: 0.1529s). Check your callbacks.
# 97/97 [==============================] - 23s 238ms/step - loss: 1.6210 - accuracy: 0.6897 - val_loss: 0.6421 - val_accuracy: 0.7375
#  2/97 [..............................] - ETA: 18s - loss: 1.5731 - accuracy: 0.7344WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0777s vs `on_train_batch_end` time: 0.1489s). Check your callbacks.
# 97/97 [==============================] - 23s 240ms/step - loss: 1.5570 - accuracy: 0.7141 - val_loss: 0.5960 - val_accuracy: 0.7500
#  2/97 [..............................] - ETA: 17s - loss: 1.5317 - accuracy: 0.7031WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0683s vs `on_train_batch_end` time: 0.1532s). Check your callbacks.
# 97/97 [==============================] - 24s 242ms/step - loss: 1.5260 - accuracy: 0.7079 - val_loss: 0.5740 - val_accuracy: 0.7437
#  2/97 [..............................] - ETA: 18s - loss: 1.1456 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0738s vs `on_train_batch_end` time: 0.1567s). Check your callbacks.
# 97/97 [==============================] - 24s 244ms/step - loss: 1.5203 - accuracy: 0.7215 - val_loss: 0.6376 - val_accuracy: 0.7406
#  2/97 [..............................] - ETA: 18s - loss: 1.7689 - accuracy: 0.6719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0723s vs `on_train_batch_end` time: 0.1559s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.4485 - accuracy: 0.7322 - val_loss: 0.8045 - val_accuracy: 0.6641
#  2/97 [..............................] - ETA: 18s - loss: 1.1428 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0704s vs `on_train_batch_end` time: 0.1559s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.3797 - accuracy: 0.7517 - val_loss: 0.5355 - val_accuracy: 0.7703
#  2/97 [..............................] - ETA: 18s - loss: 1.6438 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0707s vs `on_train_batch_end` time: 0.1574s). Check your callbacks.
# 97/97 [==============================] - 24s 244ms/step - loss: 1.3735 - accuracy: 0.7540 - val_loss: 0.5605 - val_accuracy: 0.7578
#  2/97 [..............................] - ETA: 18s - loss: 1.3700 - accuracy: 0.7656WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0708s vs `on_train_batch_end` time: 0.1553s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.3558 - accuracy: 0.7621 - val_loss: 0.5203 - val_accuracy: 0.7906
#  2/97 [..............................] - ETA: 18s - loss: 1.1806 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0681s vs `on_train_batch_end` time: 0.1577s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 1.3266 - accuracy: 0.7593 - val_loss: 0.5831 - val_accuracy: 0.7469
#  2/97 [..............................] - ETA: 18s - loss: 1.0276 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0732s vs `on_train_batch_end` time: 0.1570s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2966 - accuracy: 0.7634 - val_loss: 0.5591 - val_accuracy: 0.7609
#  2/97 [..............................] - ETA: 18s - loss: 1.3326 - accuracy: 0.6719WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0704s vs `on_train_batch_end` time: 0.1565s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 1.2693 - accuracy: 0.7790 - val_loss: 0.6113 - val_accuracy: 0.7453
#  2/97 [..............................] - ETA: 18s - loss: 1.6915 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0757s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2898 - accuracy: 0.7796 - val_loss: 0.5402 - val_accuracy: 0.7609
#  2/97 [..............................] - ETA: 18s - loss: 1.0479 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0746s vs `on_train_batch_end` time: 0.1570s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2692 - accuracy: 0.7816 - val_loss: 0.4906 - val_accuracy: 0.7844
#  2/97 [..............................] - ETA: 18s - loss: 0.9979 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0742s vs `on_train_batch_end` time: 0.1584s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2302 - accuracy: 0.7910 - val_loss: 0.5262 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 18s - loss: 1.1613 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0776s vs `on_train_batch_end` time: 0.1568s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2276 - accuracy: 0.7900 - val_loss: 0.4640 - val_accuracy: 0.8031
#  2/97 [..............................] - ETA: 18s - loss: 1.2456 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0738s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.2041 - accuracy: 0.7936 - val_loss: 0.5429 - val_accuracy: 0.7641
#  2/97 [..............................] - ETA: 18s - loss: 1.3679 - accuracy: 0.7188WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0725s vs `on_train_batch_end` time: 0.1567s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.1363 - accuracy: 0.8075 - val_loss: 0.5127 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 18s - loss: 1.1657 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0758s vs `on_train_batch_end` time: 0.1569s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.1865 - accuracy: 0.8004 - val_loss: 0.4987 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 18s - loss: 0.9663 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0714s vs `on_train_batch_end` time: 0.1538s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.1304 - accuracy: 0.8075 - val_loss: 0.5312 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 18s - loss: 1.2998 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0689s vs `on_train_batch_end` time: 0.1577s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.1267 - accuracy: 0.8095 - val_loss: 0.6076 - val_accuracy: 0.7516
#  2/97 [..............................] - ETA: 18s - loss: 1.2483 - accuracy: 0.6875WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0727s vs `on_train_batch_end` time: 0.1553s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.1361 - accuracy: 0.8056 - val_loss: 0.5115 - val_accuracy: 0.7891
#  2/97 [..............................] - ETA: 18s - loss: 0.9406 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0703s vs `on_train_batch_end` time: 0.1578s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0514 - accuracy: 0.8212 - val_loss: 0.5278 - val_accuracy: 0.7984
#  2/97 [..............................] - ETA: 18s - loss: 0.7920 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0738s vs `on_train_batch_end` time: 0.1556s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0861 - accuracy: 0.8124 - val_loss: 0.5787 - val_accuracy: 0.7594
#  2/97 [..............................] - ETA: 18s - loss: 1.4060 - accuracy: 0.7500WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0723s vs `on_train_batch_end` time: 0.1559s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0690 - accuracy: 0.8199 - val_loss: 0.4759 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.7715 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0745s vs `on_train_batch_end` time: 0.1575s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0443 - accuracy: 0.8273 - val_loss: 0.5064 - val_accuracy: 0.8078
#  2/97 [..............................] - ETA: 18s - loss: 1.2721 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0697s vs `on_train_batch_end` time: 0.1578s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0514 - accuracy: 0.8192 - val_loss: 0.5283 - val_accuracy: 0.7922
#  2/97 [..............................] - ETA: 18s - loss: 1.4204 - accuracy: 0.7812WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0726s vs `on_train_batch_end` time: 0.1572s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 1.0199 - accuracy: 0.8325 - val_loss: 0.4990 - val_accuracy: 0.8109
#  2/97 [..............................] - ETA: 18s - loss: 0.7836 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0699s vs `on_train_batch_end` time: 0.1583s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 1.0048 - accuracy: 0.8397 - val_loss: 0.4979 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 18s - loss: 0.9087 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0740s vs `on_train_batch_end` time: 0.1572s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.9882 - accuracy: 0.8416 - val_loss: 0.4945 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 18s - loss: 1.2495 - accuracy: 0.7969WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0717s vs `on_train_batch_end` time: 0.1577s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.9866 - accuracy: 0.8400 - val_loss: 0.5160 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.6821 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0716s vs `on_train_batch_end` time: 0.1564s). Check your callbacks.
# 97/97 [==============================] - 24s 244ms/step - loss: 0.9177 - accuracy: 0.8510 - val_loss: 0.6039 - val_accuracy: 0.8125
#  2/97 [..............................] - ETA: 18s - loss: 1.2024 - accuracy: 0.8125WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0719s vs `on_train_batch_end` time: 0.1571s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.9509 - accuracy: 0.8423 - val_loss: 0.5209 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 13s - loss: 1.3243 - accuracy: 0.8049WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0722s vs `on_train_batch_end` time: 0.1574s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.9498 - accuracy: 0.8494 - val_loss: 0.5690 - val_accuracy: 0.7906
#  2/97 [..............................] - ETA: 18s - loss: 0.9084 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0704s vs `on_train_batch_end` time: 0.1557s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.8882 - accuracy: 0.8578 - val_loss: 0.5197 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.8161 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0725s vs `on_train_batch_end` time: 0.1565s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.9105 - accuracy: 0.8488 - val_loss: 0.5341 - val_accuracy: 0.8266
#  2/97 [..............................] - ETA: 18s - loss: 1.0205 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0734s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.8812 - accuracy: 0.8582 - val_loss: 0.6230 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.6710 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0725s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.8533 - accuracy: 0.8627 - val_loss: 0.5282 - val_accuracy: 0.8000
#  2/97 [..............................] - ETA: 18s - loss: 1.0624 - accuracy: 0.8438WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0704s vs `on_train_batch_end` time: 0.1555s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.8293 - accuracy: 0.8653 - val_loss: 0.5160 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.5479 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0729s vs `on_train_batch_end` time: 0.1558s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.8361 - accuracy: 0.8663 - val_loss: 0.5777 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.6301 - accuracy: 0.9219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0711s vs `on_train_batch_end` time: 0.1570s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.7902 - accuracy: 0.8773 - val_loss: 0.5077 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 18s - loss: 0.6153 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0695s vs `on_train_batch_end` time: 0.1556s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.7670 - accuracy: 0.8757 - val_loss: 0.5863 - val_accuracy: 0.7937
#  2/97 [..............................] - ETA: 18s - loss: 0.7962 - accuracy: 0.8281WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0701s vs `on_train_batch_end` time: 0.1590s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.7369 - accuracy: 0.8806 - val_loss: 0.5745 - val_accuracy: 0.7937
#  2/97 [..............................] - ETA: 18s - loss: 0.9213 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0728s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.7808 - accuracy: 0.8812 - val_loss: 0.5479 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.7320 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0702s vs `on_train_batch_end` time: 0.1565s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.7178 - accuracy: 0.8825 - val_loss: 0.6189 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.5821 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0724s vs `on_train_batch_end` time: 0.1564s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.7123 - accuracy: 0.8861 - val_loss: 0.5659 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 18s - loss: 0.6661 - accuracy: 0.8594WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0672s vs `on_train_batch_end` time: 0.1564s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.6968 - accuracy: 0.8832 - val_loss: 0.5475 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 18s - loss: 0.7024 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0721s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.6394 - accuracy: 0.8942 - val_loss: 0.5605 - val_accuracy: 0.7984
#  2/97 [..............................] - ETA: 18s - loss: 0.3439 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0740s vs `on_train_batch_end` time: 0.1570s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.6014 - accuracy: 0.9033 - val_loss: 0.6012 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 18s - loss: 0.4531 - accuracy: 0.9219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0723s vs `on_train_batch_end` time: 0.1566s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.6068 - accuracy: 0.9049 - val_loss: 0.6393 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.4628 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0723s vs `on_train_batch_end` time: 0.1567s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.6044 - accuracy: 0.9111 - val_loss: 0.6250 - val_accuracy: 0.8016
#  2/97 [..............................] - ETA: 18s - loss: 0.4234 - accuracy: 0.8906WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0706s vs `on_train_batch_end` time: 0.1563s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.5672 - accuracy: 0.9111 - val_loss: 0.6800 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.3662 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0694s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.5403 - accuracy: 0.9130 - val_loss: 0.8175 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.5617 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0724s vs `on_train_batch_end` time: 0.1570s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4939 - accuracy: 0.9231 - val_loss: 0.6826 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 18s - loss: 0.7907 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0771s vs `on_train_batch_end` time: 0.1575s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.5362 - accuracy: 0.9156 - val_loss: 0.6781 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 18s - loss: 0.6156 - accuracy: 0.9219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0752s vs `on_train_batch_end` time: 0.1559s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.5281 - accuracy: 0.9224 - val_loss: 0.7655 - val_accuracy: 0.8016
#  2/97 [..............................] - ETA: 18s - loss: 0.5799 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0731s vs `on_train_batch_end` time: 0.1560s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4823 - accuracy: 0.9260 - val_loss: 0.6931 - val_accuracy: 0.8234
#  2/97 [..............................] - ETA: 18s - loss: 0.3644 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0748s vs `on_train_batch_end` time: 0.1566s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.4953 - accuracy: 0.9257 - val_loss: 0.6038 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.3434 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0732s vs `on_train_batch_end` time: 0.1572s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4296 - accuracy: 0.9296 - val_loss: 0.7610 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.3911 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0724s vs `on_train_batch_end` time: 0.1592s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4666 - accuracy: 0.9234 - val_loss: 0.6636 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 18s - loss: 0.2993 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0719s vs `on_train_batch_end` time: 0.1553s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4477 - accuracy: 0.9322 - val_loss: 0.6447 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.4932 - accuracy: 0.8750WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0709s vs `on_train_batch_end` time: 0.1568s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4271 - accuracy: 0.9367 - val_loss: 0.6978 - val_accuracy: 0.8125
#  2/97 [..............................] - ETA: 18s - loss: 0.4433 - accuracy: 0.9219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0716s vs `on_train_batch_end` time: 0.1587s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4060 - accuracy: 0.9400 - val_loss: 0.7203 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 18s - loss: 0.2130 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0729s vs `on_train_batch_end` time: 0.1571s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.4001 - accuracy: 0.9354 - val_loss: 0.5834 - val_accuracy: 0.8219
#  2/97 [..............................] - ETA: 18s - loss: 0.2769 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0710s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.3517 - accuracy: 0.9438 - val_loss: 0.8211 - val_accuracy: 0.8047
#  2/97 [..............................] - ETA: 18s - loss: 0.3221 - accuracy: 0.9062WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0723s vs `on_train_batch_end` time: 0.1589s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.3855 - accuracy: 0.9396 - val_loss: 0.7740 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.4772 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0726s vs `on_train_batch_end` time: 0.1569s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.3760 - accuracy: 0.9416 - val_loss: 0.7606 - val_accuracy: 0.7812
#  2/97 [..............................] - ETA: 18s - loss: 0.2790 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0684s vs `on_train_batch_end` time: 0.1565s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.3817 - accuracy: 0.9361 - val_loss: 0.7775 - val_accuracy: 0.8156
#  2/97 [..............................] - ETA: 18s - loss: 0.4568 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0714s vs `on_train_batch_end` time: 0.1580s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.3357 - accuracy: 0.9458 - val_loss: 0.9777 - val_accuracy: 0.7781
#  2/97 [..............................] - ETA: 18s - loss: 0.4857 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0751s vs `on_train_batch_end` time: 0.1575s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2939 - accuracy: 0.9565 - val_loss: 0.9464 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 18s - loss: 0.1789 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0728s vs `on_train_batch_end` time: 0.1581s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.3325 - accuracy: 0.9435 - val_loss: 0.7604 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.1698 - accuracy: 0.9844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0685s vs `on_train_batch_end` time: 0.1566s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.3222 - accuracy: 0.9500 - val_loss: 0.9747 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 18s - loss: 0.1990 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0706s vs `on_train_batch_end` time: 0.1562s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.3069 - accuracy: 0.9477 - val_loss: 0.8166 - val_accuracy: 0.8234
#  2/97 [..............................] - ETA: 18s - loss: 0.1472 - accuracy: 0.9844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0726s vs `on_train_batch_end` time: 0.1569s). Check your callbacks.
# 97/97 [==============================] - 24s 245ms/step - loss: 0.2559 - accuracy: 0.9604 - val_loss: 0.9668 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.1495 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0686s vs `on_train_batch_end` time: 0.1563s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2446 - accuracy: 0.9611 - val_loss: 0.7721 - val_accuracy: 0.8234
#  2/97 [..............................] - ETA: 18s - loss: 0.0493 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0725s vs `on_train_batch_end` time: 0.1553s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2437 - accuracy: 0.9604 - val_loss: 0.8761 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 18s - loss: 0.3062 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0764s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.3046 - accuracy: 0.9494 - val_loss: 0.9157 - val_accuracy: 0.8062
#  2/97 [..............................] - ETA: 18s - loss: 0.1542 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0731s vs `on_train_batch_end` time: 0.1572s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2402 - accuracy: 0.9636 - val_loss: 0.9686 - val_accuracy: 0.7937
#  2/97 [..............................] - ETA: 18s - loss: 0.4091 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0706s vs `on_train_batch_end` time: 0.1585s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2683 - accuracy: 0.9604 - val_loss: 0.7847 - val_accuracy: 0.8203
#  2/97 [..............................] - ETA: 18s - loss: 0.0193 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0714s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2171 - accuracy: 0.9662 - val_loss: 0.9080 - val_accuracy: 0.8031
#  2/97 [..............................] - ETA: 18s - loss: 0.3044 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0719s vs `on_train_batch_end` time: 0.1561s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2315 - accuracy: 0.9659 - val_loss: 0.9173 - val_accuracy: 0.8031
#  2/97 [..............................] - ETA: 18s - loss: 0.3127 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0775s vs `on_train_batch_end` time: 0.1565s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2465 - accuracy: 0.9611 - val_loss: 0.8804 - val_accuracy: 0.7875
#  2/97 [..............................] - ETA: 18s - loss: 0.4811 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0707s vs `on_train_batch_end` time: 0.1571s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2798 - accuracy: 0.9572 - val_loss: 0.9989 - val_accuracy: 0.7922
#  2/97 [..............................] - ETA: 18s - loss: 0.2959 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0740s vs `on_train_batch_end` time: 0.1577s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2310 - accuracy: 0.9607 - val_loss: 0.8599 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 18s - loss: 0.0424 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0742s vs `on_train_batch_end` time: 0.1571s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2143 - accuracy: 0.9627 - val_loss: 0.9248 - val_accuracy: 0.7953
#  2/97 [..............................] - ETA: 18s - loss: 0.3718 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0703s vs `on_train_batch_end` time: 0.1557s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2002 - accuracy: 0.9669 - val_loss: 0.8837 - val_accuracy: 0.8141
#  2/97 [..............................] - ETA: 18s - loss: 0.5361 - accuracy: 0.9375WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0719s vs `on_train_batch_end` time: 0.1577s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.1904 - accuracy: 0.9692 - val_loss: 1.0346 - val_accuracy: 0.7859
#  2/97 [..............................] - ETA: 18s - loss: 0.3998 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0711s vs `on_train_batch_end` time: 0.1573s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.1933 - accuracy: 0.9688 - val_loss: 1.1179 - val_accuracy: 0.7844
#  2/97 [..............................] - ETA: 18s - loss: 0.0229 - accuracy: 0.9844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0773s vs `on_train_batch_end` time: 0.1580s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.1766 - accuracy: 0.9685 - val_loss: 1.0021 - val_accuracy: 0.8172
#  2/97 [..............................] - ETA: 18s - loss: 0.1381 - accuracy: 0.9688WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0693s vs `on_train_batch_end` time: 0.1558s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2347 - accuracy: 0.9682 - val_loss: 0.9032 - val_accuracy: 0.8094
#  2/97 [..............................] - ETA: 18s - loss: 0.2638 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0740s vs `on_train_batch_end` time: 0.1564s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.2044 - accuracy: 0.9649 - val_loss: 1.0298 - val_accuracy: 0.8031
#  2/97 [..............................] - ETA: 18s - loss: 0.0236 - accuracy: 1.0000WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0665s vs `on_train_batch_end` time: 0.1553s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.1734 - accuracy: 0.9727 - val_loss: 1.2033 - val_accuracy: 0.7922
#  2/97 [..............................] - ETA: 18s - loss: 0.1563 - accuracy: 0.9844WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0687s vs `on_train_batch_end` time: 0.1576s). Check your callbacks.
# 97/97 [==============================] - 24s 247ms/step - loss: 0.1495 - accuracy: 0.9763 - val_loss: 1.0231 - val_accuracy: 0.7969
#  2/97 [..............................] - ETA: 18s - loss: 0.1507 - accuracy: 0.9531WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0777s vs `on_train_batch_end` time: 0.1557s). Check your callbacks.
# 97/97 [==============================] - 24s 246ms/step - loss: 0.2101 - accuracy: 0.9682 - val_loss: 0.9015 - val_accuracy: 0.8188

# %%
print("Loss of the model is - " , model.evaluate(x_test,y_test)[0]*100)
print("Accuracy of the model is - " , model.evaluate(x_test,y_test)[1]*100 , "%")
# Out:
# 22/22 [==============================] - 2s 69ms/step - loss: 0.9169 - accuracy: 0.8163
# Loss of the model is -  91.6888177394867
# 22/22 [==============================] - 2s 69ms/step - loss: 0.9169 - accuracy: 0.8163
# Accuracy of the model is -  81.62962794303894 %

# %%
print(history[0].history)
# Out:
# {'loss': [2.373941421508789], 'accuracy': [0.33073678612709045], 'val_loss': [1.1318129301071167], 'val_accuracy': [0.328125]}

# %%
epochs = [i for i in range(100)]
fig , ax = plt.subplots(1,2)
train_acc = []
train_loss = []
val_acc = []
val_loss = []
for h in history:
    train_acc.append(h.history['accuracy'])
    train_loss.append(h.history['loss'])    
    val_acc.append(h.history['val_accuracy'])
    val_loss.append(h.history['val_loss'])
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Validation Accuracy')
ax[0].set_title('Training & Validation Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'g-o' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'r-o' , label = 'Validation Loss')
ax[1].set_title('Testing Accuracy & Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Training & Validation Loss")
plt.show()

# %%
predictions = model.predict_classes(x_test)
y_test_num = [np.where(r==1)[0][0] for r in y_test]
names = ['Pneumonia Bacteria', 'Pneumonia Virus','Normal']


print(classification_report(y_test_num, predictions, target_names = names))
# Out:
# WARNING:tensorflow:From <ipython-input-26-f7104ff3924c>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#                     precision    recall  f1-score   support
#
# Pneumonia Bacteria       0.82      0.72      0.77       223
#    Pneumonia Virus       0.70      0.81      0.75       220
#             Normal       0.95      0.92      0.93       232
#
#           accuracy                           0.82       675
#          macro avg       0.82      0.81      0.82       675
#       weighted avg       0.82      0.82      0.82       675

# %%
cm = confusion_matrix(y_test_num,predictions)
cm = pd.DataFrame(cm , index = names , columns = names)
cm.index.name = 'Actual'
cm.columns.name = 'Predicted'

group_counts = ["{0:0.0f}".format(value) for value in cm.to_numpy().flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.to_numpy().flatten()/np.sum(cm.to_numpy())]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(3,3)

plt.figure(figsize = (10,10))
sns.heatmap(cm,
            annot=labels,
            cmap= "coolwarm",
            linecolor = 'black',
            linewidth = 1,
            fmt='')
